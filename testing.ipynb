# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from get_text import *
from scipy.stats import norm

# %%
#takes 30 mins to run, so DO NOT RUN unless necessary!!!
data = generate_detect()
# Out:
# 2023-05-16 21:30:33.707136: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
df = pd.read_csv('results_1.csv')

# %%
df["detected"] = 0
df.loc[df['prob'] >= 0.95, 'detected'] = 1

# %%
hand = df[df['type'] == 'Non-Generated'].copy()
soft = df[df['type'] == 'Soft Watermark'].copy()
hard = df[df['type'] == 'Hard Watermark'].copy()

# %%
f1 = {}
fp = 3
tp_non = 97

f1["hard_f1"] =  1
f1["non_gen_f1"] = 97 / (97 + 3/2)
f1["soft_.7_f1"] = 38 / (38 + 62/2)
f1["soft_1.4_f1"] = 73 / (74 + (27/2))
f1
# Out:
# {'hard_f1': 1, 'non_gen_f1': 0.97, 'soft_.7_f1': 0.38, 'soft_1.4_f1': 0.73}

# %%
precision = {}
recall = {}
for item, val in grouped_new.items():
    if item != "Non-Generated":
        precision[item] = val / (val + 3)
    else:
        precision[item] = sum(grouped_new) -
# Out:
# 100
# 3
# 38
# 73

# %%
for k, v in grouped_new.items():
    print(k, v)
# Out:
# Hard Watermark 100
# Non-Generated 3
# Soft Watermark
#  (delta = 0.7) 38
# Soft Watermark
#  (delta = 1.4) 73

# %%
write_csv("soft_delta_1.4.csv", data)

# %%
soft_df = pd.read_csv('soft_delta_1.4.csv')
soft_df["detected"] = 0
soft_df.loc[soft_df['prob'] >= 0.95, 'detected'] = 1
soft_df["type"] = "soft_1.4"

# %%
# Group the dataframe by 'type' and calculate the sum of 'detected' for each group
grouped_df2 = soft_df.groupby('type')['detected'].sum()

# Plot the bar graph
ax = grouped_df2.plot(kind='bar')

# Add the percentages to the bars
for i, v in enumerate(grouped_df2):
    ax.text(i, v + 0.5, f'({v:.1f}%)', ha='center')

# Set labels and title
plt.xlabel('Type')
plt.ylabel('Count of Detected')
plt.title('Detected Counts by Type')

# Rotate the x-axis labels
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
new_df = pd.concat([df, soft_df], ignore_index=True)

# %%
new_df['type'] = new_df['type'].replace('soft_1.4', 'Soft Watermark\n (delta = 1.4)')
new_df['type'] = new_df['type'].replace('Soft Watermark', 'Soft Watermark\n (delta = 0.7)')
# Group the dataframe by 'type' and calculate the sum of 'detected' for each group
grouped_new = new_df.groupby('type')['detected'].sum()

# Plot the bar graph
ax = grouped_new.plot(kind='bar')

# Add the percentages to the bars
for i, v in enumerate(grouped_new):
    ax.text(i, v + 0.5, f'({v:.1f}%)', ha='center')

# Set labels and title
plt.xlabel('Type')
plt.ylabel('Count of Detected')
plt.title('Detected Counts by Type')

# Rotate the x-axis labels
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
# Filter the dataframe to keep only rows where the column value is "Hard Watermark"
filtered_df = new_df[new_df.type == 'Hard Watermark']
probs = sorted(filtered_df["prob"])

# Create a histogram of the column with value "Hard Watermark"
plt.hist(probs)
plt.ylabel("Count")
plt.xlabel("p-values")
plt.title(f"p-values of Hard Watermark Text")
#Get current x-tick labels

plt.show()

# %%
# Function to calculate z-score
def calculate_z(p_value):
    return norm.ppf(p_value/2)

# Apply the function to create the 'z' column
new_df['z'] = new_df['prob'].apply(calculate_z)

# %%
hard = new_df[new_df.type == 'Hard Watermark']
hand = new_df[new_df.type == 'Non-Generated']
soft_14 = new_df[new_df.type == 'Soft Watermark\n (delta = 1.4)']
soft_07 = new_df[new_df.type == 'Soft Watermark\n (delta = 0.7)']

# %%
final = []
key = []
for i in range(10):
    random.seed(i)
    idx = random.randint(0, 100)
    eval = []
    eval.append([hard.iloc[i]["text"], hard.iloc[i]["type"]])
    eval.append([hand.iloc[i]["text"], hand.iloc[i]["type"]])
    eval.append([soft_07.iloc[i]["text"], soft_07.iloc[i]["type"]])
    eval.append([soft_14.iloc[i]["text"], soft_14.iloc[i]["type"]])
    random.shuffle(eval)
    final.append([x[0] for x in eval])
    key.append([x[1] for x in eval])

# %%
ranks = [[4, 1, 3, 2], [3, 2, 1, 4], [1, 2, 4, 3], [3, 1, 4, 2], [4, 1, 2, 3], [2, 3, 4, 1], [3, 2, 1, 4], [4, 2, 3, 1], [1, 4, 2, 3], [2, 1, 4, 3]]

# %%
quality = [zip(key[i][j], ranks[i][j]) for i in range(4) for j in range(10)]
qualitative = pd.DataFrame(list(q) for q in quality)
qualitative.drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[148], line 1
# ----> 1 quality = [zip(key[i][j], ranks[i][j]) for i in range(4) for j in range(10)]
#       2 qualitative = pd.DataFrame(list(q) for q in quality)
#       3 qualitative.drop_duplicates()
#
# Cell In[148], line 1, in <listcomp>(.0)
# ----> 1 quality = [zip(key[i][j], ranks[i][j]) for i in range(4) for j in range(10)]
#       2 qualitative = pd.DataFrame(list(q) for q in quality)
#       3 qualitative.drop_duplicates()
#
# TypeError: 'int' object is not iterable
